# %% [markdown]
# # Vessel Value Pipeline
#
# Loads the Clarksons vessel-value series, computes monthly returns, and saves a processed version for later use. Source data is proprietary and not included in this repo.

# %%
from src.load_vessel_value import load_vessel_value
from src.config import PRIVATE_DATA

# %%
vessel = load_vessel_value()

vessel.head()
# Out:
#           date  ship_value  ship_return
# 410 2010-03-31       37.50     0.034483
# 411 2010-04-30       39.50     0.053333
# 412 2010-05-31       41.00     0.037975
# 413 2010-06-30       40.25    -0.018293
# 414 2010-07-31       38.00    -0.055901

# %%
vessel.tail()
# Out:
#           date  ship_value  ship_return
# 598 2025-11-30        33.0     0.015385
# 599 2025-12-31        33.0     0.000000
# 600 2026-01-31        34.0     0.030303
# 601 2026-02-28        36.0     0.058824
# 602 2026-03-31        37.0     0.027778

# %%
vessel.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193 entries, 410 to 602
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         193 non-null    datetime64[us]
#  1   ship_value   193 non-null    float64
#  2   ship_return  193 non-null    float64
# dtypes: datetime64[us](1), float64(2)
# memory usage: 4.7 KB

# %%
vessel.describe()
# Out:
#                              date  ship_value  ship_return
# count                         193  193.000000   193.000000
# mean   2018-03-31 11:41:20.829015   26.480570     0.001124
# min           2010-03-31 00:00:00   13.000000    -0.117647
# 25%           2014-03-31 00:00:00   22.000000    -0.020408
# 50%           2018-03-31 00:00:00   24.500000     0.000000
# 75%           2022-03-31 00:00:00   32.500000     0.027778
# max           2026-03-31 00:00:00   41.000000     0.235294
# std                           NaN    7.255472     0.045584

# %%
vessel.isna().sum()
# Out:
# date           0
# ship_value     0
# ship_return    0
# dtype: int64

# %%
vessel.to_csv(
    PRIVATE_DATA / "vessel_value_monthly.csv",
    index=False
)

print("Saved successfully.")
# Out:
# Saved successfully.

# %% [markdown]
# ## Data Validation

# %%
vessel.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193 entries, 410 to 602
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         193 non-null    datetime64[us]
#  1   ship_value   193 non-null    float64
#  2   ship_return  193 non-null    float64
# dtypes: datetime64[us](1), float64(2)
# memory usage: 4.7 KB

# %%
vessel.isna().sum()
# Out:
# date           0
# ship_value     0
# ship_return    0
# dtype: int64

# %%
vessel.describe()
# Out:
#                              date  ship_value  ship_return
# count                         193  193.000000   193.000000
# mean   2018-03-31 11:41:20.829015   26.480570     0.001124
# min           2010-03-31 00:00:00   13.000000    -0.117647
# 25%           2014-03-31 00:00:00   22.000000    -0.020408
# 50%           2018-03-31 00:00:00   24.500000     0.000000
# 75%           2022-03-31 00:00:00   32.500000     0.027778
# max           2026-03-31 00:00:00   41.000000     0.235294
# std                           NaN    7.255472     0.045584

# %%
vessel.plot(
    x="date",
    y="ship_value",
    figsize=(10, 5),
    title="5YO Kamsarmax/Panamax Vessel Value"
)
# Out:
# <Axes: title={'center': '5YO Kamsarmax/Panamax Vessel Value'}, xlabel='date'>
