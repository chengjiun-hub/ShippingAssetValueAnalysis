# %% [markdown]
# # Public Market Data Pipeline
#
# Pulls VIX and WTI data from Yahoo Finance, resamples to monthly, and saves the result for use in later analysis.

# %%
from src.download_market_data import build_public_market_data
from src.config import PUBLIC_DATA

# %%
market_data = build_public_market_data()

market_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#             vix_level  wti_price  vix_return  wti_return
# Date
# 2010-03-31  17.590000  83.760002   -0.097949    0.051469
# 2010-04-30  22.049999  86.150002    0.253553    0.028534
# 2010-05-31  32.070000  73.970001    0.454422   -0.141381
# 2010-06-30  34.540001  75.629997    0.077019    0.022441
# 2010-07-31  23.500000  78.949997   -0.319629    0.043898

# %%
market_data.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 197 entries, 2010-03-31 to 2026-07-31
# Freq: ME
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vix_level   197 non-null    float64
#  1   wti_price   197 non-null    float64
#  2   vix_return  197 non-null    float64
#  3   wti_return  197 non-null    float64
# dtypes: float64(4)
# memory usage: 7.7 KB

# %%
market_data.to_csv(
    PUBLIC_DATA / "market_data_monthly.csv"
)

print("Saved successfully.")
# Out:
# Saved successfully.
